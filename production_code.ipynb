# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
# Assume user input
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'], dtype='object').reshape(1, 7)

# %%
pipe.predict(test_input2)
# Out:
# c:\Users\Noman Traders\Desktop\WebDevCourse\my projects\Learn Python\02-py-libraries\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\Noman Traders\Desktop\WebDevCourse\my projects\Learn Python\02-py-libraries\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import cloudpickle
import numpy as np
import pandas as pd

model = cloudpickle.load(open("model.pkl", "rb"))

# %%
def predict_price(arr):
    cols = [
        "area","bedrooms","bathrooms","stories","mainroad","guestroom",
        "basement","hotwaterheating","airconditioning","parking",
        "prefarea","furnishingstatus"
    ]
    
    df = pd.DataFrame([arr], columns=cols)
    return model.predict(df)[0]

# %%
price = predict_price([8000,3,2,4,'yes','no','no','no','yes',1,'no','furnished'])
print(f"Price: {price:.2f}")
# Out:
# Price: 7259381.74
